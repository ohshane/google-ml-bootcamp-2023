# %% [markdown]
# ### Neural Network model

# %% [markdown]
# $$
# \mathbf x =
# \begin{bmatrix}
#     x_1 \\
#     x_2 \\
#     x_3
# \end{bmatrix},
# \quad
# \mathbf w_1^{[1]} =
# \begin{bmatrix}
#     w_1 \\
#     w_2 \\
#     w_3
# \end{bmatrix},
# \quad
# b_1^{[1]}
# $$
#
# $$
# \def\horz{\text{---}}
# \mathbf w^{[1]\intercal} \mathbf x + b^{[1]} =
# \begin{bmatrix}
#     \horz & \mathbf w_1^{[1] \intercal} & \horz
# \end{bmatrix}
# \begin{bmatrix}
#     \vert \\
#     \mathbf x \\
#     \vert
# \end{bmatrix}
# + b_1^{[1]}
# $$

# %% [markdown]
# $$
# \mathbf x =
# \begin{bmatrix}
#     x_1 \\
#     x_2 \\
#     x_3
# \end{bmatrix},
# \quad
#
# \mathbf w_1^{[1]} =
# \begin{bmatrix}
#     w_1 \\
#     w_2 \\
#     w_3
# \end{bmatrix},
# \quad
#
# \mathbf w_2^{[1]} =
# \begin{bmatrix}
#     w_1 \\
#     w_2 \\
#     w_3
# \end{bmatrix},
# \quad
#
# \mathbf w_3^{[1]} =
# \begin{bmatrix}
#     w_1 \\
#     w_2 \\
#     w_3
# \end{bmatrix},
# \quad
#
# \mathbf w_4^{[1]} =
# \begin{bmatrix}
#     w_1 \\
#     w_2 \\
#     w_3
# \end{bmatrix},
# \quad
#
# b_1^{[1]},
# \quad
# b_2^{[1]},
# \quad
# b_3^{[1]},
# \quad
# b_4^{[1]}
# $$
#
# $$
# \mathbf x =
# \begin{bmatrix}
#     x_1 \\
#     x_2 \\
#     x_3
# \end{bmatrix},
# \quad
#
# \def\horz{\text{---}}
# \mathbf W^{[1]} =
# \begin{bmatrix}
#     \horz & \mathbf w_1^{[1] \intercal} & \horz \\
#     \horz & \mathbf w_2^{[1] \intercal} & \horz \\
#     \horz & \mathbf w_3^{[1] \intercal} & \horz \\
#     \horz & \mathbf w_4^{[1] \intercal} & \horz \\
# \end{bmatrix},
# \quad
#
# \mathbf b^{[1]} =
# \begin{bmatrix}
#     b_1^{[1]} \\
#     b_2^{[1]} \\
#     b_3^{[1]} \\
#     b_4^{[1]} \\
# \end{bmatrix}
# $$
#
# $$
# \def\horz{\text{---}}
# \mathbf W^{[1]} \mathbf x + \mathbf b^{[1]} =
# \begin{bmatrix}
#     \horz & \mathbf w_1^{[1] \intercal} & \horz \\
#     \horz & \mathbf w_2^{[1] \intercal} & \horz \\
#     \horz & \mathbf w_3^{[1] \intercal} & \horz \\
#     \horz & \mathbf w_4^{[1] \intercal} & \horz \\
# \end{bmatrix}
# \begin{bmatrix}
#     \vert \\
#     \mathbf x \\
#     \vert
# \end{bmatrix}
# +
# \begin{bmatrix}
#     b_1^{[1]} \\
#     b_2^{[1]} \\
#     b_3^{[1]} \\
#     b_4^{[1]} \\
# \end{bmatrix}
# $$
